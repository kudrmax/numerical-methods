# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

# %%
def f(x):
    return x[0] ** 2 + 2 * x[1] ** 2 + np.exp(x[0]) * np.cos(x[1] - 1)

x1, x2 = -2, 1
y1, y2 = -1, 1

# %%
X = np.linspace(x1, x2, 400)
Y = np.linspace(y1, y2, 400)
X, Y = np.meshgrid(X, Y)
Z = f([X, Y])

fig = plt.figure(figsize=(14, 7))

ax1 = fig.add_subplot(121, projection='3d')
ax1.plot_surface(X, Y, Z, cmap='viridis')
ax1.set_title('3D Surface Plot')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('f(x, y)')

ax2 = fig.add_subplot(122)
contour = ax2.contour(X, Y, Z, 50)
ax2.set_title('Contour Plot')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
plt.colorbar(contour, ax=ax2)

plt.show()

# %%
fig = plt.figure(figsize=(14, 7))
ax3 = fig.add_subplot(122)
ax3.imshow(Z, extent=[x1, x2, y1, y2], origin='lower', aspect='auto')
ax3.set_title('Surface Plot')
ax3.set_xlabel('x')
ax3.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
initial_guess = [0, 0]

result = minimize(f, initial_guess, tol=1e-6)
min_x, min_y = result.x
min_f = result.fun

print(f"Минимальное значение функции: {min_f} в точке ({min_x}, {min_y})")
# Out:
# Минимальное значение функции: 0.41435312789245854 в точке (-0.1553346040458045, -0.19944312500711342)

# %%
fig = plt.figure(figsize=(14, 7))
ax3 = fig.add_subplot(122)
ax3.imshow(Z, extent=[x1, x2, y1, y2], origin='lower', aspect='auto')
ax3.set_title('Surface Plot')
ax3.set_xlabel('x')
ax3.set_ylabel('y')
ax3.scatter(min_x, min_y)
